# %% [markdown]
# # Formatting Dataset.

# %% [markdown]
# Indian data is given as:

# %% [markdown]
# ## <b> 1. Dataset formatter <b> .

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data1.csv')
df.head()
# Out:
#    publish_date headline_category  \
# 0      20010102           unknown
# 1      20010102           unknown
# 2      20010102           unknown
# 3      20010102           unknown
# 4      20010102           unknown
#
#                                        headline_text
# 0  Status quo will not be disturbed at Ayodhya; s...
# 1                Fissures in Hurriyat over Pak visit
# 2              America's unwanted heading for India?
# 3                 For bigwigs; it is destination Goa
# 4               Extra buses to clear tourist traffic

# %%
df.count()
# Out:
# publish_date         3424067
# headline_category    3424067
# headline_text        3424067
# dtype: int64

# %%
df1 = df.sample(5000)
df1.to_csv('Publications/TOI.csv',index = False)
df1.head()
# Out:
#          publish_date headline_category  \
# 3241945      20200101     city.ludhiana
# 1398648      20120624             india
# 2624155      20170417       city.indore
# 3004849      20181014       city.bhopal
# 2733622      20170920   sports.football
#
#                                              headline_text
# 3241945  Punjab: Congress government to allow anti-CAA ...
# 1398648          NCPCR seeks explanation from Haryana govt
# 2624155  HC on alleged Simhastha irregularities: Take i...
# 3004849          Rahul to visit Datia; Gwalior from Monday
# 2733622  Premier Futsal: Bengaluru Royals rout Mumbai W...

# %%
df = pd.read_csv('data2.csv')
df.head()
# Out:
#                     author                                            content  \
# 0                The Quint  Tulsi Gabbard, the first Hindu lawmaker from H...
# 1            Pushpesh Pant  Swami Vivekananda ranks among the highest in t...
# 2  Meeran Chadha Borwankar  In the news for the wrong reasons, the Central...
# 3             Mayukh Ghosh  Reminiscing about the past is a dreadful tool ...
# 4           Akanksha Kumar  : Akanksha Kumar : Sandeep Suman Twenty-three ...
#
#          date                                                tag  \
# 0  2018-11-13                                      Tulsi Gabbard
# 1  2018-07-03  Swami Vivekananda,Hinduism,Tolerance,Politics ...
# 2  2018-07-18  Modi Government,Central Bureau of Investigatio...
# 3  2018-05-14  Satyajit Ray,Shyam Benegal,Smita Patil,Politic...
# 4  2018-04-30  Tihar Jail,Supreme Court of India,Life Impriso...
#
#                                                title  \
# ...

# %%
df['website'].value_counts()
# Out:
# firstpost    5621
# quint        4889
# scroll       1494
# thewire      1437
# opindia       743
# catchnews     643
# dailyo        519
# Name: website, dtype: int64

# %%
df1 = df.loc[df['website'] == 'quint']
df1.to_csv('Publications/QT.csv',index = False)
df1.head()
# Out:
#                     author                                            content  \
# 0                The Quint  Tulsi Gabbard, the first Hindu lawmaker from H...
# 1            Pushpesh Pant  Swami Vivekananda ranks among the highest in t...
# 2  Meeran Chadha Borwankar  In the news for the wrong reasons, the Central...
# 3             Mayukh Ghosh  Reminiscing about the past is a dreadful tool ...
# 4           Akanksha Kumar  : Akanksha Kumar : Sandeep Suman Twenty-three ...
#
#          date                                                tag  \
# 0  2018-11-13                                      Tulsi Gabbard
# 1  2018-07-03  Swami Vivekananda,Hinduism,Tolerance,Politics ...
# 2  2018-07-18  Modi Government,Central Bureau of Investigatio...
# 3  2018-05-14  Satyajit Ray,Shyam Benegal,Smita Patil,Politic...
# 4  2018-04-30  Tihar Jail,Supreme Court of India,Life Impriso...
#
#                                                title  \
# ...

# %%
df2 = df.loc[df['website'] == 'firstpost']
df2.to_csv('Publications/FP.csv',index = False)
df2.head()
# Out:
#                         author  \
# 4889  Asian News International
# 4890      Press Trust of India
# 4891      Press Trust of India
# 4892      Press Trust of India
# 4893      Press Trust of India
#
#                                                 content        date  \
# 4889  Wanaparthy (Telangana): Union Home Minister Ra...  2018-11-29
# 4890  Chief Minister Arvind Kejriwal on Wednesday or...  2018-11-29
# 4891   Slamming the revision of GDP data under the U...  2018-11-29
# 4892   The HD Kumarawamy-led JD(S)-Congress ministry...  2018-11-29
# 4893  : All India Majlis-e-Ittehadul Muslimeen (AIMI...  2018-11-29
#
#                                                     tag  \
# 4889  14th Finance Commission,Andhra Pradesh,Assembl...
# 4890  AAP,Arvind Kejriwal,BJP,Delhi,Imran Hussain,Mo...
# 4891  Anand Sharma,Arun Jaitley,BJP,Congress,GDP,Nar...
# 4892  Congress,Dinesh Gundu Rao,G Parameshwara,HD Ku...
# 4893  AIMIM,All India Majlis-E-Ittehadul Muslimeen,A...
#
# ...
