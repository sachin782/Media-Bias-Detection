# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("FP.csv")
df.head(20)
# Out:
#                      author  \
# 0      Press Trust of India
# 1      Press Trust of India
# 2      Press Trust of India
# 3      Press Trust of India
# 4      Press Trust of India
# 5   Indo-Asian News Service
# 6               FP Politics
# 7                  FP Staff
# 8           Sandipan Sharma
# 9      Press Trust of India
# 10             Kashif Kakvi
# 11                 FP Staff
# 12  Indo-Asian News Service
# 13     Press Trust of India
# 14     Press Trust of India
# 15                 FP Staff
# 16                 FP Staff
# 17                 FP Staff
# 18      Sursingh Rajpurohit
# 19              FP Politics
#
#                                               content        date  \
# 0   Chief Minister Arvind Kejriwal on Wednesday or...  2018-11-29
# 1    Slamming the revision of GDP data under the U...  2018-11-29
# 2    The HD Kumarawamy-led JD(S)-Congress ministry...  2018-11-29
# 3   : All India Majlis-e-Ittehadul Muslimeen (AIMI...  2018-11-29
# ...

# %%
df['Label'].value_counts()
# Out:
# -1    996
#  0      3
# Name: Label, dtype: int64

# %%
df1 = df[df['Label']== -1]
df1.head(20)
# Out:
#                      author  \
# 0      Press Trust of India
# 1      Press Trust of India
# 2      Press Trust of India
# 3      Press Trust of India
# 4      Press Trust of India
# 5   Indo-Asian News Service
# 6               FP Politics
# 7                  FP Staff
# 8           Sandipan Sharma
# 9      Press Trust of India
# 10             Kashif Kakvi
# 11                 FP Staff
# 12  Indo-Asian News Service
# 13     Press Trust of India
# 14     Press Trust of India
# 15                 FP Staff
# 16                 FP Staff
# 17                 FP Staff
# 18      Sursingh Rajpurohit
# 19              FP Politics
#
#                                               content        date  \
# 0   Chief Minister Arvind Kejriwal on Wednesday or...  2018-11-29
# 1    Slamming the revision of GDP data under the U...  2018-11-29
# 2    The HD Kumarawamy-led JD(S)-Congress ministry...  2018-11-29
# 3   : All India Majlis-e-Ittehadul Muslimeen (AIMI...  2018-11-29
# ...
